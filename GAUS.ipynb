# %%
Gaus()
# Out:
# Metodo para las funciones
# x=0.25+0.25y
# y=0.25+0.25x+0.25z
# z=0.25+0.25y+0.25w
# w=0.25+0.25z
# [0, 0.25, 0.328125, 0.353515625, 0.36187744140625, 0.3633460998535156, 0.363588809967041, 0.3636285811662674, 0.3636350901797414, 0.3636361552635208, 0.36363632954089553]
# [0, 0.3125, 0.4140625, 0.447509765625, 0.4533843994140625, 0.45435523986816406, 0.4545143246650696, 0.45454036071896553, 0.4545446210540831, 0.4545453181635821, 0.45454543222967914]
# [0, 0.328125, 0.4365234375, 0.45166015625, 0.4540748596191406, 0.4544684886932373, 0.4545328617095947, 0.45454339403659105, 0.4545451173908077, 0.454545399377821, 0.4545454455185336]
# [0, 0.33203125, 0.359130859375, 0.3629150390625, 0.36351871490478516, 0.3636171221733093, 0.3636332154273987, 0.36363584850914776, 0.36363627934770193, 0.36363634984445525, 0.3636363613796334]

# %%
def gx(y):
    return (0.25+(0.25*y))
def gy(x, z):
  return (0.25+(0.25*x)+(0.25*z))
def gz(y, w):
  return (0.25+(0.25*y)+(0.25*w))
def gw(z):
  return (0.25+(0.25*z))

# %%
import matplotlib.pyplot as plt
import math
def  Gaus():
  print("Metodo para las funciones")
  print("x=0.25+0.25y")
  print("y=0.25+0.25x+0.25z")
  print("z=0.25+0.25y+0.25w")
  print("w=0.25+0.25z")
  fg1p()

def fg1p():
  x_vec=[]
  x_vec.append(0)
  y_vec=[]
  y_vec.append(0)
  z_vec=[]
  z_vec.append(0)
  w_vec=[]
  w_vec.append(0)
  contador = 0
  while(contador < 10):
    x_vec.append(gx(y_vec[contador]))
    y_vec.append(gy(x_vec[contador+1],z_vec[contador]))
    z_vec.append(gz(y_vec[contador+1],w_vec[contador]))
    w_vec.append(gw(z_vec[contador+1]))
    contador += 1
  print(x_vec)
  print(y_vec)
  print(z_vec)
  print(w_vec)
  plt.plot(x_vec, label = "x_r")
  plt.plot(y_vec, label = "x_y")
  plt.plot(z_vec, label = "x_z")
  plt.plot(w_vec, label = "x_w")
  plt.legend()
  plt.show()
